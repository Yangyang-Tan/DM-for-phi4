# %%
import numpy as np
import h5py

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10.npy")[:,:,:,0:16]

# %%
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=04.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=04.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=49.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=49.npy", data1)

# %%
cfgs=h5py.File("../data/cfgs_k=0.5_l=2.5_32^3_t=10.jld2", "r")
cfgs['cfgs'][0:16,:,:,:].transpose(1,2,3,0).shape
np.save("data/cfgs_k=0.5_l=2.5_32^3_t=10_short.npy", cfgs['cfgs'][0:16,:,:,:].transpose(1,2,3,0))

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=99.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=99.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=00.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=00.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=01.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=01.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=00_steps=0300.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=00_steps=0300.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=00_steps=0100.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=00_steps=0100.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_epoch=386.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_epoch=386.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.8.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.8.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.6.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.6.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.4.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.4.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.2.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.2.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.9.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.9.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.85.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.85.npy", data1)

# %%
data1=np.load("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_tau=0.7.npy")[:,:,:,0:16]
np.save("data/phi4_3d_L32_k0.5_l2.5_ncsnpp_t=10_short_tau=0.7.npy", data1)
