# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = 'trainingdata/cfgs_wolff_fahmc_k=0.2_l=0.9_64^3.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

# %%
import matplotlib.pyplot as plt

# %%
cfgs.shape
# Out:
# (2560, 64, 64, 64)

# %%
n=4
fig, axes = plt.subplots(n, n, figsize=(n * 2, n * 2))
mid_z = 64 // 2
for i, ax in enumerate(axes.flatten()):
    if i < cfgs.shape[0]:
        ax.imshow(cfgs[10*i,mid_z,:,:], cmap="viridis")
        # print(i)
    ax.axis("off")
plt.suptitle(f"3D phi4 samples (z={mid_z} slice)")
plt.tight_layout()

# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = 'trainingdata/cfgs_wolff_fahmc_k=0.2_l=0.9_64^3.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

print('=== 原始数据 ===')
print(f'Shape: {cfgs.shape}')
print(f'Range: [{cfgs.min():.4f}, {cfgs.max():.4f}]')

# Normalize (same as FieldDataModule)
cfgs_min = cfgs.min()
cfgs_max = cfgs.max()
cfgs_norm = ((cfgs - cfgs_min) / (cfgs_max - cfgs_min) - 0.5) * 2

print('\\n=== 归一化后数据 (与 FieldDataModule 一致) ===')
print(f'Range: [{cfgs_norm.min():.4f}, {cfgs_norm.max():.4f}]')

# Compute distances on normalized data
n_samples = 500
indices = np.random.choice(len(cfgs), n_samples, replace=False)
samples_norm = cfgs_norm[indices].reshape(n_samples, -1).astype(np.float32)

print(f'\\n=== 归一化数据的配对距离 ({n_samples} samples) ===')
distances = pdist(samples_norm, metric='euclidean')
print(f'Maximum: {distances.max():.4f}')
print(f'Mean:    {distances.mean():.4f}')
print(f'Min:     {distances.min():.4f}')

print(f'\\n理论最大值 (64x64, [-1,1]): sqrt(64*64*4) = {np.sqrt(128*128*4):.4f}')
# Out:
# === 原始数据 ===
# Shape: (2560, 64, 64, 64)
# Range: [-2.2104, 2.2176]
# \n=== 归一化后数据 (与 FieldDataModule 一致) ===
# Range: [-1.0000, 1.0000]
# \n=== 归一化数据的配对距离 (500 samples) ===
# Maximum: 344.1974
# Mean:    268.5805
# Min:     178.2466
# \n理论最大值 (64x64, [-1,1]): sqrt(64*64*4) = 256.0000

# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = '../data/cfgs_k=0.5_l=0.022_32^2_t=10.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

print('=== 原始数据 ===')
print(f'Shape: {cfgs.shape}')
print(f'Range: [{cfgs.min():.4f}, {cfgs.max():.4f}]')

# Normalize (same as FieldDataModule)
cfgs_min = cfgs.min()
cfgs_max = cfgs.max()
cfgs_norm = ((cfgs - cfgs_min) / (cfgs_max - cfgs_min) - 0.5) * 2

print('\\n=== 归一化后数据 (与 FieldDataModule 一致) ===')
print(f'Range: [{cfgs_norm.min():.4f}, {cfgs_norm.max():.4f}]')

# Compute distances on normalized data
n_samples = 4000
indices = np.random.choice(len(cfgs), n_samples, replace=False)
samples_norm = cfgs_norm[indices].reshape(n_samples, -1).astype(np.float32)

print(f'\\n=== 归一化数据的配对距离 ({n_samples} samples) ===')
distances = pdist(samples_norm, metric='euclidean')
print(f'Maximum: {distances.max():.4f}')
print(f'Mean:    {distances.mean():.4f}')
print(f'Min:     {distances.min():.4f}')

print(f'\\n理论最大值 (32x32, [-1,1]): sqrt(32*32*4) = {np.sqrt(32*32*4):.4f}')
# Out:
# === 原始数据 ===
# Shape: (10240, 32, 32)
# Range: [-6.1702, 6.1449]
# \n=== 归一化后数据 (与 FieldDataModule 一致) ===
# Range: [-1.0000, 1.0000]
# \n=== 归一化数据的配对距离 (4000 samples) ===
# Maximum: 50.0317
# Mean:    31.9853
# Min:     3.9758
# \n理论最大值 (32x32, [-1,1]): sqrt(32*32*4) = 64.0000

# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = '../data/cfgs_k=0.5_l=0.022_16^2_t=10.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

print('=== 原始数据 ===')
print(f'Shape: {cfgs.shape}')
print(f'Range: [{cfgs.min():.4f}, {cfgs.max():.4f}]')

# Normalize (same as FieldDataModule)
cfgs_min = cfgs.min()
cfgs_max = cfgs.max()
cfgs_norm = ((cfgs - cfgs_min) / (cfgs_max - cfgs_min) - 0.5) * 2

print('\\n=== 归一化后数据 (与 FieldDataModule 一致) ===')
print(f'Range: [{cfgs_norm.min():.4f}, {cfgs_norm.max():.4f}]')

# Compute distances on normalized data
n_samples = 8000
indices = np.random.choice(len(cfgs), n_samples, replace=False)
samples_norm = cfgs_norm[indices].reshape(n_samples, -1).astype(np.float16)

print(f'\\n=== 归一化数据的配对距离 ({n_samples} samples) ===')
distances = pdist(samples_norm, metric='euclidean')
print(f'Maximum: {distances.max():.4f}')
print(f'Mean:    {distances.mean():.4f}')
print(f'Min:     {distances.min():.4f}')

print(f'\\n理论最大值 (16x16, [-1,1]): sqrt(16*16*4) = {np.sqrt(16*16*4):.4f}')
# Out:
# === 原始数据 ===
# Shape: (10240, 16, 16)
# Range: [-6.0994, 6.1439]
# \n=== 归一化后数据 (与 FieldDataModule 一致) ===
# Range: [-1.0000, 1.0000]
# \n=== 归一化数据的配对距离 (8000 samples) ===
# Maximum: 25.7622
# Mean:    15.6212
# Min:     1.0687
# \n理论最大值 (16x16, [-1,1]): sqrt(16*16*4) = 32.0000

# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = '../data/cfgs_k=0.5_l=0.022_8^2_t=10.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

print('=== 原始数据 ===')
print(f'Shape: {cfgs.shape}')
print(f'Range: [{cfgs.min():.4f}, {cfgs.max():.4f}]')

# Normalize (same as FieldDataModule)
cfgs_min = cfgs.min()
cfgs_max = cfgs.max()
cfgs_norm = ((cfgs - cfgs_min) / (cfgs_max - cfgs_min) - 0.5) * 2

print('\\n=== 归一化后数据 (与 FieldDataModule 一致) ===')
print(f'Range: [{cfgs_norm.min():.4f}, {cfgs_norm.max():.4f}]')

# Compute distances on normalized data
n_samples = 10240
indices = np.random.choice(len(cfgs), n_samples, replace=False)
samples_norm = cfgs_norm[indices].reshape(n_samples, -1).astype(np.float32)

print(f'\\n=== 归一化数据的配对距离 ({n_samples} samples) ===')
distances = pdist(samples_norm, metric='euclidean')
print(f'Maximum: {distances.max():.4f}')
print(f'Mean:    {distances.mean():.4f}')
print(f'Min:     {distances.min():.4f}')

print(f'\\n理论最大值 (8x8, [-1,1]): sqrt(8*8*4) = {np.sqrt(8*8*4):.4f}')
# Out:
# === 原始数据 ===
# Shape: (10240, 8, 8)
# Range: [-6.1029, 6.0472]
# \n=== 归一化后数据 (与 FieldDataModule 一致) ===
# Range: [-1.0000, 1.0000]
# \n=== 归一化数据的配对距离 (10240 samples) ===
# Maximum: 13.3404
# Mean:    6.9234
# Min:     0.3792
# \n理论最大值 (8x8, [-1,1]): sqrt(8*8*4) = 16.0000

# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = '../data/cfgs_k=0.5_l=2.5_32^3_t=10.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

print('=== 原始数据 ===')
print(f'Shape: {cfgs.shape}')
print(f'Range: [{cfgs.min():.4f}, {cfgs.max():.4f}]')

# Normalize (same as FieldDataModule)
cfgs_min = cfgs.min()
cfgs_max = cfgs.max()
cfgs_norm = ((cfgs - cfgs_min) / (cfgs_max - cfgs_min) - 0.5) * 2

print('\\n=== 归一化后数据 (与 FieldDataModule 一致) ===')
print(f'Range: [{cfgs_norm.min():.4f}, {cfgs_norm.max():.4f}]')

# Compute distances on normalized data
n_samples = 1000
indices = np.random.choice(len(cfgs), n_samples, replace=False)
samples_norm = cfgs_norm[indices].reshape(n_samples, -1).astype(np.float32)

print(f'\\n=== 归一化数据的配对距离 ({n_samples} samples) ===')
distances = pdist(samples_norm, metric='euclidean')
print(f'Maximum: {distances.max():.4f}')
print(f'Mean:    {distances.mean():.4f}')
print(f'Min:     {distances.min():.4f}')

print(f'\\n理论最大值 (32x32, [-1,1]): sqrt(32*32*32*4) = {np.sqrt(32*32*32*4):.4f}')
# Out:
# === 原始数据 ===
# Shape: (10240, 32, 32, 32)
# Range: [-1.5157, 1.5140]
# \n=== 归一化后数据 (与 FieldDataModule 一致) ===
# Range: [-1.0000, 1.0000]
# \n=== 归一化数据的配对距离 (1000 samples) ===
# Maximum: 204.2146
# Mean:    184.1408
# Min:     164.3159
# \n理论最大值 (32x32, [-1,1]): sqrt(32*32*32*4) = 362.0387

# %%
import h5py
import numpy as np
from scipy.spatial.distance import pdist

# Load data
data_path = '../data/cfgs_k=0.5_l=2.5_64^3_t=10.jld2'
with h5py.File(data_path, 'r') as f:
    cfgs = np.array(f['cfgs'])

print('=== 原始数据 ===')
print(f'Shape: {cfgs.shape}')
print(f'Range: [{cfgs.min():.4f}, {cfgs.max():.4f}]')

# Normalize (same as FieldDataModule)
cfgs_min = cfgs.min()
cfgs_max = cfgs.max()
cfgs_norm = ((cfgs - cfgs_min) / (cfgs_max - cfgs_min) - 0.5) * 2

print('\\n=== 归一化后数据 (与 FieldDataModule 一致) ===')
print(f'Range: [{cfgs_norm.min():.4f}, {cfgs_norm.max():.4f}]')

# Compute distances on normalized data
n_samples = 4000
indices = np.random.choice(len(cfgs), n_samples, replace=False)
samples_norm = cfgs_norm[indices].reshape(n_samples, -1).astype(np.float64)

print(f'\\n=== 归一化数据的配对距离 ({n_samples} samples) ===')
distances = pdist(samples_norm, metric='euclidean')
print(f'Maximum: {distances.max():.4f}')
print(f'Mean:    {distances.mean():.4f}')
print(f'Min:     {distances.min():.4f}')

print(f'\\n理论最大值 (64x64, [-1,1]): sqrt(64*64*64*4) = {np.sqrt(64*64*64*4):.4f}')
# Out:
# === 原始数据 ===
# Shape: (10240, 64, 64, 64)
# Range: [-1.5151, 1.5166]
# \n=== 归一化后数据 (与 FieldDataModule 一致) ===
# Range: [-1.0000, 1.0000]
# \n=== 归一化数据的配对距离 (4000 samples) ===
# Maximum: 543.1260
# Mean:    520.6265
# Min:     498.6859
# \n理论最大值 (64x64, [-1,1]): sqrt(64*64*64*4) = 1024.0000
